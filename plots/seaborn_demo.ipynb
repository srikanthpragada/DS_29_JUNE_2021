# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
sns.set(style="dark")

# %%
tips = sns.load_dataset("tips")
flights = sns.load_dataset("flights")

# %% [markdown]
# ## Categorical plots

# %% [markdown]
# #### boxplot()

# %%
ax = sns.boxplot(x="day",y="tip", data = tips)

# %%
ax = sns.boxplot(x="day",y="tip", data = tips, showfliers=False, meanline=True, showmeans=True)

# %%
ax = sns.boxplot(x="day",y="total_bill", hue="sex", data = tips)
ax.set_xlabel("Week")
t = ax.set_title("Day-wise Total Bill for Male and Female")

# %%
ax = sns.boxplot(x="sex",y="total_bill", hue="day", data = tips, width=0.5) 
ax.figure.set_size_inches(10,5)

# %%
ax = sns.boxplot(x="day",y="tip", hue="smoker", data = tips)

# %%
# Add extra parameters realted to matplotlib
plt.figure(figsize=(10,5))
ax = sns.boxplot(x="day",y="total_bill",hue="sex", data = tips,
            showmeans=True, meanline=True, showfliers=False, width=0.5)

# %% [markdown]
# #### countplot()

# %%
t = sns.countplot(x="day",data = tips, color='red')

# %%
# plt.figure(figsize=(15,6))
sns.countplot(x="day",data = tips, hue="sex")
# Out:
# <AxesSubplot:xlabel='day', ylabel='count'>

# %%
# plt.figure(figsize=(15,6))
sns.set(style="whitegrid")
sns.countplot(x="smoker",data = tips, hue="day")
# Out:
# <AxesSubplot:xlabel='smoker', ylabel='count'>

# %% [markdown]
# #### barplot()

# %%
# Default estimator is mean 
sns.set(style="dark")
ax = sns.barplot(x="day",y="total_bill", ci = False, data = tips,estimator=sum)

# %%
sns.barplot(x="sex",y="total_bill", hue="day", ci=False, data = tips [ tips.time == 'Dinner'],estimator=sum)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %%
sns.barplot(x="day",y="total_bill",data=tips,hue="size",ci=False, estimator=sum)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %% [markdown]
# #### catplot()

# %%
# Figure level API
sns.catplot(x="day",y="total_bill",data=tips, col="smoker", kind='bar', ci=False, estimator=sum)

# %%
# Figure level API
ax = sns.catplot(x="size",y="total_bill",data=tips, col="day", kind='bar', ci=False)
ax.fig.suptitle("Day-wise Average Total Bill for Different Sizes")
ax.fig.set_size_inches(15,5)
ax.fig.subplots_adjust(top=.90)

# %%
ax = sns.catplot(x="day",y="total_bill",data=tips,row="smoker", kind='bar', ci=False)
plt.gcf().set_size_inches(10,5)

# %%
seltips = tips[tips['size'].isin([2,3,4])]
sns.catplot(x="day",y="total_bill",data=seltips,col="size", kind='box')
plt.gcf().set_size_inches(10,5)  # Change current figure size

# %%
sns.stripplot(x="day",y="total_bill",data=tips)   # Strip plot
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(x="day",y="total_bill", hue='smoker',data=tips)   # Strip
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(x="day",y="total_bill",data=tips)   # Swarm plot
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(x="day",y="total_bill",hue='time',data=tips, dodge=True)   # Swarm plot
# Out:
# C:\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 6.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 10.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ## Flights

# %%
flights.sample(5)
# Out:
#      year month  passengers
# 20   1950   Sep         158
# 47   1952   Dec         194
# 109  1958   Feb         318
# 48   1953   Jan         196
# 40   1952   May         183

# %%
plt.figure(figsize=(15,5))
#plt.xticks(rotation=60)
plt.title('Passengers by Month')
ax = sns.barplot(x="month",y="passengers",data=flights,ci=False,estimator=np.sum)

# %% [markdown]
# ## Relational plots

# %% [markdown]
# #### scatterplot()

# %%
sns.scatterplot(x="total_bill",y="tip", data=tips)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x="total_bill",y="tip", data=tips, size="smoker")
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x="total_bill",y="tip", hue='sex', style="smoker", data=tips)
plt.gcf().set_size_inches(15,5)

# %%
flights.head(10)
# Out:
#    year      month  passengers
# 0  1949    January         112
# 1  1949   February         118
# 2  1949      March         132
# 3  1949      April         129
# 4  1949        May         121
# 5  1949       June         135
# 6  1949       July         148
# 7  1949     August         148
# 8  1949  September         136
# 9  1949    October         119

# %% [markdown]
# #### lineplot()

# %%
sns.lineplot(x='month', y = 'passengers', estimator=sum, data = flights,ci = False)
plt.gcf().set_size_inches(15,5)

# %%
plt.figure(figsize=(15,5))
sns.lineplot(x="year", y="passengers", estimator=sum, data=flights,ci=False)
# Out:
# <AxesSubplot:xlabel='year', ylabel='passengers'>

# %%
sns.lineplot(x='day', y = 'tip', data=tips, estimator=sum, hue='sex', ci= False)
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %% [markdown]
# #### relplot()

# %%
# Figure level 
sns.relplot(x="total_bill",y="tip",col="sex", hue="smoker", data=tips)

# %% [markdown]
# ## Distribution plots

# %% [markdown]
# #### histplot()

# %%
sns.histplot(tips['tip'],kde=False)
# Out:
# <AxesSubplot:xlabel='tip', ylabel='Count'>

# %%
sns.histplot(tips['tip'],bins=5, kde=False)
# Out:
# <AxesSubplot:xlabel='tip', ylabel='Count'>

# %%
tips.tip.hist(bins=5)
# Out:
# <AxesSubplot:>

# %%
#Fig-level
sns.displot(x="tip",col='sex', data = tips, kde=False, bins = 5)

# %%
tips['tip_per'] = tips['tip'] / tips['total_bill']

# %%
sns.displot(x="tip_per",col='sex', data = tips, kde=False, bins = 10)

# %%
sns.barplot(x='sex', y = 'tip_per', data = tips, ci = False)   # Who is more generous - male or female?
# Out:
# <AxesSubplot:xlabel='sex', ylabel='tip_per'>

# %%
# Add extra parameters realted to matplotlib
plt.figure(figsize=(10,5))
ax = sns.boxplot(x="day",y="total_bill",hue="sex", data = tips,
            showmeans=True, meanline=True, showfliers=False, width=0.5)

# %%
sns.rugplot(tips.tip)
# Out:
# <AxesSubplot:xlabel='tip'>

# %%
sns.rugplot(tips['total_bill'], height=.1)
# Out:
# <AxesSubplot:xlabel='total_bill'>

# %%
sns.displot(x = 'total_bill', col='smoker', data=tips,rug=True)

# %% [markdown]
# ## Multi-plot

# %% [markdown]
# ### pairplot()

# %%
sns.pairplot(tips,vars=['total_bill','tip'])
plt.gcf().set_size_inches(10,6)

# %%
sns.pairplot(tips,vars=['total_bill','tip'], hue='smoker', diag_kind='kde')
plt.gcf().set_size_inches(15,8)

# %% [markdown]
# #### jointplot()

# %%
sns.jointplot(x='total_bill', y = 'tip', data = tips)

# %%
sns.jointplot(x='total_bill', y = 'size', data = tips)

# %%
sns.jointplot(x='total_bill', y = 'tip', hue='sex', data = tips)

# %% [markdown]
# ## Regression Plot

# %% [markdown]
# #### regplot()

# %%
sns.regplot(x="total_bill",y='tip', data=tips, ci=False)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# #### lmplot()

# %%
sns.lmplot(x="total_bill",y='tip',hue="smoker", data=tips,ci=False)

# %%
sns.lmplot(x="total_bill",y='tip',hue="sex", data=tips,ci=False)

# %%
sns.lmplot(x="total_bill",y='tip',hue="time",data=tips,ci=False)

# %%
sns.lmplot(x="total_bill",y='tip',col='day', data=tips,ci=False)

# %%
sns.residplot(x="total_bill",y='tip',data=tips)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
g = sns.FacetGrid(tips,col="day")
g = g.map(sns.residplot, "total_bill",  "tip")

# %%
g = sns.FacetGrid(tips,col="sex")
g = g.map(sns.residplot, "total_bill",  "tip")

# %%
tips.sex.value_counts()
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %% [markdown]
# ## Matrix plots

# %%
day_tips = tips.groupby('day', as_index=False)[['tip','total_bill']].sum()

# %%
day_tips
# Out:
#     day     tip  total_bill
# 0  Thur  171.83     1096.33
# 1   Fri   51.96      325.88
# 2   Sat  260.40     1778.40
# 3   Sun  247.39     1627.16

# %%
ds = tips.pivot_table (index = "day", columns = "time", values="total_bill", aggfunc=np.sum)
ds
# Out:
# time    Lunch   Dinner
# day
# Thur  1077.55    18.78
# Fri     89.92   235.96
# Sat      0.00  1778.40
# Sun      0.00  1627.16

# %%
sns.heatmap(ds)
# Out:
# <AxesSubplot:xlabel='time', ylabel='day'>

# %%
sns.heatmap(ds,cmap='YlGnBu', annot=True, fmt=".2f")
# Out:
# <AxesSubplot:xlabel='time', ylabel='day'>

# %%
fl_summary = flights.pivot('month','year','passengers')
# print(fl_summary)
ax = sns.heatmap(fl_summary,annot=True, fmt=".0f")
plt.gcf().set_size_inches(20,15)

# %%
fl_summary = flights.pivot('month','year','passengers')
ax = sns.heatmap(fl_summary,annot=True, fmt=".0f", cbar=False)
plt.gcf().set_size_inches(20,10)

# %%
cm = tips[['total_bill','tip','size']].corr()
print(cm)
sns.heatmap(cm, annot=True)
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000
# <AxesSubplot:>
